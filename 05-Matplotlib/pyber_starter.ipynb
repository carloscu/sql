# %%
# %matplotlib notebook
#%matplotlib inline

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data_to_load_df = pd.read_csv(city_data_to_load)
ride_data_to_load_df = pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset
combined_city_and_ride_df = pd.merge(city_data_to_load_df, ride_data_to_load_df, how="outer", on="city")

# Display the data table for preview
combined_city_and_ride_df.head()

#city_data_to_load_df.head()
#ride_data_to_load_df.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
# Split up our data into groups based upon 'city'
city_groups = combined_city_and_ride_df.groupby("city")
average_fare_per_city = city_groups["fare"].mean()
#average_fare_per_city.head()

total_number_of_rides_per_city = city_groups["ride_id"].count()
#total_number_of_rides_per_city.head()

total_number_of_drivers_per_city = city_groups["driver_count"].count()
#total_number_of_drivers_per_city.head()

city_type = city_groups["type"]
#city_type.head()

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
city_type = np.arrange(combined_city_and_ride_df["type"])
urban_number_of_rides_per_city = 

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure
# Out:
#   File "<ipython-input-3-ad712a8bca04>", line 3
#     urban_number_of_rides_per_city =
#                                      ^
# SyntaxError: invalid syntax

# %%
# Show plot
plt.show()

# %%
# Split up our data into groups based upon 'city'
city_groups = combined_city_and_ride_df.groupby("city")
average_fare_per_city = city_groups["fare"].mean()
#average_fare_per_city.head()

total_number_of_rides_per_city = city_groups["ride_id"].count()
#total_number_of_rides_per_city.head()

total_number_of_drivers_per_city = city_groups["driver_count"].count()
#total_number_of_drivers_per_city.head()

city_type = city_groups["type"]
#city_type.head()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

city_types = combined_city_and_ride_df.groupby("type")

total_fares_by_city_type = city_types.sum()
total_fares_by_city_type.head()

fares_by_type = total_fares_by_city_type.keys()

# Build Pie Chart
fares_pie = total_fares_by_city_type.plot(kind="pie", y=fares_by_type, title="Total Fares by City Type")
fares_pie.set_ylabel("Fares")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Fares')

# %%
plt.show()
plt.tight_layout()
plt.axis("equal")


# Save Figure
plt.savefig("../Images/FaresPies.png")

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
# Split up our data into groups based upon 'city type'
city_type_group_ride = combined_city_and_ride_df.groupby("type")

total_number_of_rides_per_city = city_type_group_ride["ride_id"].count()
total_number_of_rides_per_city.head()

rides_by_type = total_number_of_rides_per_city.keys()


# Build Pie Chart

rides_pie = total_number_of_rides_per_city.plot(kind="pie", y=rides_by_type, title="Total Rides by City Type")
rides_pie.set_ylabel("Rides")
# Out:
# Text(29,0.5,'Rides')

# %%
plt.show()
plt.tight_layout()
plt.axis("equal")

# Save Figure


plt.savefig("../Images/RidesPies.png")

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
city_types_drivers = combined_city_and_ride_df.groupby("type")

total_number_of_drivers_per_city = city_types_drivers["driver_count"].count()
total_number_of_drivers_per_city.head()

drivers_by_type = total_number_of_drivers_per_city.keys()

# Build Pie Charts
drivers_pie = total_number_of_drivers_per_city.plot(kind="pie", y=drivers_by_type, title="Total Drivers by City Type")
drivers_pie.set_ylabel("Drivers")
# Out:
# Text(29,0.5,'Drivers')

# %%
# Show Figure
plt.show()
plt.tight_layout()
plt.axis("equal")

# Save Figure

plt.savefig("../Images/DriversPies.png")
