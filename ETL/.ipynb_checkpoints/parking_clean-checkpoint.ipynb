# %%
import pandas as pd
import requests
import numpy as np

# %%
parking_data = "parking-citations.csv"
parking_data = pd.read_csv(parking_data)
parking_data.head()
# Out:
# C:\Users\spitc\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 0    1103341116  2015-12-21T00:00:00      1251.0      NaN          NaN
# 1    1103700150  2015-12-21T00:00:00      1435.0      NaN          NaN
# 2    1104803000  2015-12-21T00:00:00      2055.0      NaN          NaN
# 3    1104820732  2015-12-26T00:00:00      1515.0      NaN          NaN
# 4    1105461453  2015-09-15T00:00:00       115.0      NaN          NaN
#
#   RP State Plate  Plate Expiry Date  VIN  Make Body Style Color  \
# 0             CA           200304.0  NaN  HOND         PA    GY
# 1             CA           201512.0  NaN   GMC         VN    WH
# 2             CA           201503.0  NaN  NISS         PA    BK
# ...

# %%
parking_data = parking_data.loc[:, ["Ticket number", "Issue Date", "Issue time", "Make", "Body Style", "Color", "Violation Description", "variety", "Fine amount"]]

parking_data.head()
# Out:
# C:\Users\spitc\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#   Ticket number           Issue Date  Issue time  Make Body Style Color  \
# 0    1103341116  2015-12-21T00:00:00      1251.0  HOND         PA    GY
# 1    1103700150  2015-12-21T00:00:00      1435.0   GMC         VN    WH
# 2    1104803000  2015-12-21T00:00:00      2055.0  NISS         PA    BK
# 3    1104820732  2015-12-26T00:00:00      1515.0  ACUR         PA    WH
# 4    1105461453  2015-09-15T00:00:00       115.0  CHEV         PA    BK
#
#   Violation Description  variety  Fine amount
# 0    NO EVIDENCE OF REG      NaN         50.0
# 1    NO EVIDENCE OF REG      NaN         50.0
# ...

# %%
#list(parking_data['Color'].unique())

#parking_data.loc[parking_data.Color == GY, 'Color'] = 'Grey'
parking_data.Color[parking_data.Color=='GY'] = 'GREY'
parking_data.Color[parking_data.Color=='WH'] = 'WHITE'
parking_data.Color[parking_data.Color=='BK'] = 'BLACK'
parking_data.Color[parking_data.Color=='BL'] = 'BLUE'
parking_data.Color[parking_data.Color=='SI'] = 'SILVER'
parking_data.Color[parking_data.Color=='GO'] = 'GOLD'
parking_data.Color[parking_data.Color=='RE'] = 'RED'
parking_data.Color[parking_data.Color=='MA'] = 'PURPLE'
parking_data.Color[parking_data.Color=='TA'] = 'TAN'
parking_data.Color[parking_data.Color=='BU'] = 'RED'
parking_data.Color[parking_data.Color=='GR'] = 'GREEN'
parking_data.Color[parking_data.Color=='YE'] = 'YELLOW'
parking_data.Color[parking_data.Color=='OR'] = 'ORANGE'
parking_data.Color[parking_data.Color=='WT'] = 'WHITE'
parking_data.Color[parking_data.Color=='RD'] = 'RED'
parking_data.Color[parking_data.Color=='SL'] = 'SILVER'
parking_data.Color[parking_data.Color=='BN'] = 'BROWN'
parking_data.Color[parking_data.Color=='OT'] = 'MULTICOLOR'
parking_data.Color[parking_data.Color=='GN'] = 'GREEN'
parking_data.Color[parking_data.Color=='MR'] = 'MAROON'
parking_data.Color[parking_data.Color=='BG'] = 'NaN'
parking_data.Color[parking_data.Color=='PR'] = 'GREY'
parking_data.Color[parking_data.Color=='TN'] = 'TAN'
parking_data.Color[parking_data.Color=='UN'] = 'MULTICOLOR'
parking_data.Color[parking_data.Color=='PK'] = 'PINK'
parking_data.Color[parking_data.Color=='TU'] = 'TAN'
parking_data.Color[parking_data.Color=='CO'] = 'COPPER'
parking_data.Color[parking_data.Color=='BE'] = 'BROWN'
parking_data.Color[parking_data.Color=='PU'] = 'PURPLE'
parking_data.Color[parking_data.Color=='RU'] = 'RED'
parking_data.Color[parking_data.Color=='PL'] = 'MULTICOLOR'
parking_data.Color[parking_data.Color=='CR'] = 'CREAM'
parking_data.Color[parking_data.Color=='SN'] = 'BROWN'
parking_data.Color[parking_data.Color=='PE'] = 'NaN'
parking_data.Color[parking_data.Color=='BZ'] = 'BRONZE'
parking_data.Color[parking_data.Color=='PI'] = 'PINK'
parking_data.Color[parking_data.Color=='ME'] = 'RED'
parking_data.Color[parking_data.Color=='CH'] = 'CHROME'
parking_data.Color[parking_data.Color=='TE'] = 'GREEN, LGT'
parking_data.Color[parking_data.Color=='LI'] = 'NaN'
parking_data.Color[parking_data.Color=='MU'] = 'NaN'
parking_data.Color[parking_data.Color=='KH'] = 'NaN'
parking_data.Color[parking_data.Color=='GA'] = 'NaN'
parking_data.Color[parking_data.Color=='AQ'] = 'NaN'
parking_data.Color[parking_data.Color=='WI'] = 'NaN'
parking_data.Color[parking_data.Color=='OL'] = 'BLACK'
parking_data.Color[parking_data.Color=='SA'] = 'BEIGE'
parking_data.head()
# Out:
# C:\Users\spitc\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\spitc\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\spitc\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\spitc\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# ...

# %%
parking_data.to_csv('parking_db.csv')
