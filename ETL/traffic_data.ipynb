# %%
#Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
#Set File Path
json_file = "traffic_db.json"
#traffic_data_df = pd.read_json(json_file)

traffic_df = pd.read_json(json_file, typ='series')

# JSON file ran into dictionary and series error this here creates it all as a series and reads
# the column names and resets them
mbs = pd.read_json(json_file, typ='series')
mbs_columns = mbs['meta']['view']['columns']
names = [item['name'] for item in mbs_columns]
df = pd.DataFrame(data=mbs['data'],columns=names)

# %%
pd.set_option('display.max_columns', 500)
df.head()
# Out:
#        sid                                    id  position  created_at  \
# 0  2118167  EE8BC302-660F-48C4-B422-17427ECE821F   2118167  1482239054
# 1  3064529  9763533B-48A3-480A-BB54-1EF8C60849AF   3064529  1504085194
# 2  2118171  938F1DC7-DE76-45E8-AF25-361CBCC8507C   2118171  1482239054
# 3  3064530  75858866-32C1-4E6B-8C01-322CD15F33EB   3064530  1504085194
# 4  3064531  077389FD-023F-420B-909C-85034959FEF5   3064531  1504085194
#
#   created_meta  updated_at updated_meta  meta         Date Of Stop  \
# 0       498050  1482239054       498050  None  2013-09-24T00:00:00
# 1       498050  1504085194       498050  None  2017-08-29T00:00:00
# 2       498050  1482239054       498050  None  2014-12-01T00:00:00
# 3       498050  1504085194       498050  None  2017-08-29T00:00:00
# 4       498050  1504085194       498050  None  2017-08-28T00:00:00
#
#   Time Of Stop Agency                                        SubAgency  \
# ...

# %%
#list(df['Color'].unique())
# Out:
# ['BLACK',
#  'GREEN',
#  'SILVER',
#  'WHITE',
#  'GRAY',
#  'RED',
#  'GOLD',
#  'BLUE',
#  'N/A',
#  'BLUE, DARK',
#  'TAN',
#  'CREAM',
#  'PURPLE',
#  'BEIGE',
#  'BLUE, LIGHT',
#  'MAROON',
#  'GREEN, DK',
#  'GREEN, LGT',
#  'ORANGE',
#  None,
#  'BROWN',
#  'BRONZE',
#  'YELLOW',
#  'COPPER',
#  'MULTICOLOR',
#  'CAMOUFLAGE',
#  'PINK',
#  'CHROME']

# %%
new_df = df[["Description", "VehicleType", "Year", "Make", "Model", "Color","Gender"]].copy()

# %%
new_df.head()
# Out:
#                                          Description      VehicleType  Year  \
# 0  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...  02 - Automobile  2008
# 1  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...  02 - Automobile  2001
# 2                 FAILURE STOP AND YIELD AT THRU HWY  02 - Automobile  2001
# 3               FAILURE YIELD RIGHT OF WAY ON U TURN  02 - Automobile  1998
# 4  FAILURE OF DR. TO MAKE LANE CHANGE TO AVAIL. L...  02 - Automobile  2015
#
#           Make    Model   Color Gender
# 0         FORD       4S   BLACK      M
# 1       TOYOTA  COROLLA   GREEN      F
# 2        HONDA   ACCORD  SILVER      F
# 3         DODG   DAKOTA   WHITE      M
# 4  MINI COOPER       2S   WHITE      M

# %%
new_df.to_csv('traffic.csv')
